# %% [markdown]
# # 1. Test Random Environment with OpeanAI Gym

# %%
import gym
import random
from IPython import display
import matplotlib.pyplot as plt

# %%
import numpy

# %%
env = gym.make('CartPole-v0')
states = env.observation_space.shape[0]
actions = env.action_space.n
# Out:
# c:\Users\vinip\miniconda3\envs\Keras\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
import matplotlib.pyplot as plt
from IPython import display
import gym
import random

# %%
env = gym.make('CartPole-v0', render_mode = 'rgb_array')
states = env.observation_space.shape[0]
actions = env.action_space.n
# Out:
# c:\Users\vinip\miniconda3\envs\Keras\lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
def img_render(episode):
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render())
    plt.axis()
    plt.title("Step: {}" .format(episode))
    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
episodes = 10
for episode in range(1,episodes+1):
    state = env.reset()
    done = False
    score = 0
    while not done:
        
        action = random.choice([0,1])
        n_state, reward, done, info, _ = env.step(action)
        img_render(episode)
        score+=reward
        
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:10 Score:23.0

# %% [markdown]
# # 2.Create a Deep Learning Model with Keras

# %%
import numbpy as
